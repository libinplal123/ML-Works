# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\seaborn-works\\play-store-works\\cleaned_play_store.csv")
print(df.isnull().sum())
# Out:
# id                   0
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver          2
# Year                 0
# Month                0
# dtype: int64

# %%
df["Rating"]=df["Rating"].fillna(df["Rating"].mean(),inplace=True)
# Out:
# C:\Users\libin_urv2w13\AppData\Local\Temp\ipykernel_13960\2497920045.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Rating"]=df["Rating"].fillna(df["Rating"].mean(),inplace=True)

# %%
print(df.isnull().sum())
# Out:
# id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       2
# Year              0
# Month             0
# dtype: int64

# %%
df["Type"] = df["Type"].fillna(df["Type"].mode()[0],inplace=True)
print((df.isnull().sum()))
# Out:
# id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       2
# Year              0
# Month             0
# dtype: int64
# C:\Users\libin_urv2w13\AppData\Local\Temp\ipykernel_13960\547879617.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# ...

# %%
df["Current Ver"] = df["Current Ver"].fillna(df["Current Ver"].mode()[0],inplace=True)
print((df.isnull().sum()))
# Out:
# id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       0
# Android Ver       2
# Year              0
# Month             0
# dtype: int64
# C:\Users\libin_urv2w13\AppData\Local\Temp\ipykernel_13960\2321399901.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# ...

# %%
df["Android Ver"] = df["Android Ver"].fillna(df["Android Ver"].mode()[0],inplace=True)
print((df.isnull().sum()))
# Out:
# id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       0
# Android Ver       0
# Year              0
# Month             0
# dtype: int64
# C:\Users\libin_urv2w13\AppData\Local\Temp\ipykernel_13960\3116338250.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# ...
