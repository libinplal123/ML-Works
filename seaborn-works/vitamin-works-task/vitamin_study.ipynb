# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\seaborn-works\\vitamin-works-task\\vitamin_deficiency_disease_dataset (1).csv")
print(df.shape)
print(df.columns)
# Out:
# (4000, 34)
# Index(['age', 'gender', 'bmi', 'smoking_status', 'alcohol_consumption',
#        'exercise_level', 'diet_type', 'sun_exposure', 'income_level',
#        'latitude_region', 'vitamin_a_percent_rda', 'vitamin_c_percent_rda',
#        'vitamin_d_percent_rda', 'vitamin_e_percent_rda',
#        'vitamin_b12_percent_rda', 'folate_percent_rda', 'calcium_percent_rda',
#        'iron_percent_rda', 'hemoglobin_g_dl', 'serum_vitamin_d_ng_ml',
#        'serum_vitamin_b12_pg_ml', 'serum_folate_ng_ml', 'symptoms_count',
#        'symptoms_list', 'has_night_blindness', 'has_fatigue',
#        'has_bleeding_gums', 'has_bone_pain', 'has_muscle_weakness',
#        'has_numbness_tingling', 'has_memory_problems', 'has_pale_skin',
#        'disease_diagnosis', 'has_multiple_deficiencies'],
#       dtype='str')

# %%
# age and bmi plot
sns.lineplot(data=df,x="age",y="bmi",hue="gender")
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
# smoking status and bmi plot
sns.barplot(data=df,x="smoking_status",y="bmi",hue="gender")
# Out:
# <Axes: xlabel='smoking_status', ylabel='bmi'>

# %%
# exercise level and bmi plot
sns.barplot(data=df,x="exercise_level",y="bmi",hue="gender")
# Out:
# <Axes: xlabel='exercise_level', ylabel='bmi'>

# %%
# diet type and vitamin a percent rda
sns.stripplot(data=df,x="diet_type",y="vitamin_a_percent_rda",hue="gender")
# Out:
# <Axes: xlabel='diet_type', ylabel='vitamin_a_percent_rda'>

# %%
# exercise level histogram
sns.histplot(data=df,x="exercise_level")
# Out:
# <Axes: xlabel='exercise_level', ylabel='Count'>
