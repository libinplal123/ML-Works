# %%
import seaborn as sns
data=sns.load_dataset("tips")

# %%
print(data.head())
print(data.shape)
print(data.columns)
print(data.isnull().sum())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 7)
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.scatterplot(data=data,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.stripplot(data=data,x="size",y="tip",hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.histplot(data=data,x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.regplot(data=data,x="total_bill",y="tip",color="purple")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=data,x="size",y="total_bill")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.scatterplot(data=data,x="total_bill",y="tip",hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=data,x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.regplot(data=data,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=data,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=data,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(data=data,x="day",y="total_bill",estimator=np.sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=data,x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
columns = ["total_bill","tip","size"]
data[columns].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data[columns].corr(),annot=True)
# Out:
# <Axes: >
