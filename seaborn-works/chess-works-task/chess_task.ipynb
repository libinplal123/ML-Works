# %%
import seaborn as sns
import pandas as pd
data=pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\seaborn-works\\seaborn-chess-works\\games.csv")
print(data.shape)
print(data.columns)
# Out:
# (20058, 16)
# Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')

# %%
sns.barplot(data=data,x="victory_status",y="turns")
# Out:
# <Axes: xlabel='victory_status', ylabel='turns'>

# %%
sns.lineplot(data=data,x="white_rating",y="victory_status")
# Out:
# <Axes: xlabel='white_rating', ylabel='victory_status'>

# %%
sns.histplot(data=data,x="winner")
# Out:
# <Axes: xlabel='winner', ylabel='Count'>

# %%
sns.boxplot(data=data,x="winner",y="turns")
# Out:
# <Axes: xlabel='winner', ylabel='turns'>

# %%
sns.stripplot(data=data,x="victory_status",y="turns")
# Out:
# <Axes: xlabel='victory_status', ylabel='turns'>
