# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\seaborn-works\\delhi-ncr-task\\delhi_ncr_aqi_dataset.csv")
print(df.shape)
print(df.columns)
print(df.isnull().sum())
# Out:
# (201664, 25)
# Index(['datetime', 'date', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'season', 'city', 'station', 'latitude', 'longitude',
#        'pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
#        'wind_speed', 'visibility', 'aqi', 'aqi_category'],
#       dtype='object')
# datetime        0
# date            0
# year            0
# month           0
# day             0
# hour            0
# day_of_week     0
# is_weekend      0
# season          0
# city            0
# station         0
# latitude        0
# longitude       0
# pm25            0
# pm10            0
# no2             0
# so2             0
# co              0
# o3              0
# temperature     0
# humidity        0
# wind_speed      0
# visibility      0
# aqi             0
# aqi_category    0
# dtype: int64

# %%
df.dtypes
# Out:
# datetime         object
# date             object
# year              int64
# month             int64
# day               int64
# hour              int64
# day_of_week      object
# is_weekend        int64
# season           object
# city             object
# station          object
# latitude        float64
# longitude       float64
# pm25            float64
# pm10            float64
# no2             float64
# so2             float64
# co              float64
# o3              float64
# temperature     float64
# humidity          int64
# wind_speed      float64
# visibility      float64
# aqi               int64
# aqi_category     object
# dtype: object

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [datetime, date, year, month, day, hour, day_of_week, is_weekend, season, city, station, latitude, longitude, pm25, pm10, no2, so2, co, o3, temperature, humidity, wind_speed, visibility, aqi, aqi_category]
# Index: []
#
# [0 rows x 25 columns]

# %%
df["datetime"]=pd.to_datetime(df["datetime"])
df["date"]=pd.to_datetime(df["date"])
df.dtypes
# Out:
# datetime        datetime64[ns]
# date            datetime64[ns]
# year                     int64
# month                    int64
# day                      int64
# hour                     int64
# day_of_week             object
# is_weekend               int64
# season                  object
# city                    object
# station                 object
# latitude               float64
# longitude              float64
# pm25                   float64
# pm10                   float64
# no2                    float64
# so2                    float64
# co                     float64
# o3                     float64
# temperature            float64
# humidity                 int64
# wind_speed             float64
# visibility             float64
# aqi                      int64
# aqi_category            object
# dtype: object

# %%
sns.barplot(data=df,x="season",y="pm25")
# Out:
# <Axes: xlabel='season', ylabel='pm25'>

# %%
sns.barplot(data=df,x="city",y="pm10")
# Out:
# <Axes: xlabel='city', ylabel='pm10'>

# %%
sns.boxplot(data=df,x="season",y="temperature")
# Out:
# <Axes: xlabel='season', ylabel='temperature'>

# %%
sns.barplot(data=df,x="aqi_category",y="aqi")
# Out:
# <Axes: xlabel='aqi_category', ylabel='aqi'>

# %%
sns.barplot(data=df,x="day_of_week",y="aqi")
# Out:
# <Axes: xlabel='day_of_week', ylabel='aqi'>

# %%
sns.barplot(data=df,x="aqi_category",y="wind_speed")
# Out:
# <Axes: xlabel='aqi_category', ylabel='wind_speed'>
