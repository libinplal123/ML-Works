# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\Feature-Engineering\\loan-data\\loan.csv")

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')
# (4269, 13)

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [loan_id,  no_of_dependents,  education,  self_employed,  income_annum,  loan_amount,  loan_term,  cibil_score,  residential_assets_value,  commercial_assets_value,  luxury_assets_value,  bank_asset_value,  loan_status]
# Index: []

# %%
sns.lineplot(data=df,x=" income_annum",y=" loan_amount",hue=" education")
# Out:
# <Axes: xlabel=' income_annum', ylabel=' loan_amount'>

# %%
sns.barplot(data=df,x=" no_of_dependents",y=" income_annum")
# Out:
# <Axes: xlabel=' no_of_dependents', ylabel=' income_annum'>

# %%
sns.histplot(data=df,x=" income_annum")
# Out:
# <Axes: xlabel=' income_annum', ylabel='Count'>

# %%
sns.boxplot(data=df,x=" education",y=" loan_amount")
# Out:
# <Axes: xlabel=' education', ylabel=' loan_amount'>

# %%
sns.histplot(data=df,x=" loan_status")
# Out:
# <Axes: xlabel=' loan_status', ylabel='Count'>

# %%
sns.barplot(data=df,x=" loan_status",y=" cibil_score",hue=" education")
# Out:
# <Axes: xlabel=' loan_status', ylabel=' cibil_score'>
