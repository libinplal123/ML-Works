# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\matplotlib-works\\penguin-dataset\\penguin_data.csv")

# %%
print(df.columns)
print(df.shape)
print(df.isnull().sum())
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
# (344, 7)
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df["bill_length_mm"].fillna(df["bill_length_mm"].mean(),inplace=True)
print(df.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df["bill_depth_mm"].fillna(df["bill_depth_mm"].mean(),inplace=True)
print(df.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df["flipper_length_mm"].fillna(df.groupby("sex")["flipper_length_mm"].transform("mean"),inplace=True)
print(df.isnull().sum())
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          2
# sex                  0
# dtype: int64

# %%
df["sex"].fillna(df["sex"].mode()[0],inplace=True)
print(df.isnull().sum())
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# dtype: int64

# %%
df["body_mass_g"].fillna(df["body_mass_g"].mean(),inplace=True)
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# correlation between bill length and body mass
plt.plot(df.groupby("bill_length_mm")["body_mass_g"].mean())

# %%
# correlation between bill depth and body mass
plt.plot(df.groupby("bill_depth_mm")["body_mass_g"].mean())

# %%
# correlation between flipper length and body mass
plt.plot(df.groupby("flipper_length_mm")["body_mass_g"].mean())

# %%
# island wise body mass index
island_mass=df.groupby("island")["body_mass_g"].mean()
plt.bar(island_mass.index,island_mass.values)
# Out:
# <BarContainer object of 3 artists>

# %%
# species wise body mass
species_mass=df.groupby("species")["body_mass_g"].mean()
plt.bar(species_mass.index,species_mass.values)
# Out:
# <BarContainer object of 3 artists>

# %%
# body mass outliers
mass=df["body_mass_g"]
plt.boxplot(mass)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24bd42f3620>,
#   <matplotlib.lines.Line2D at 0x24bd42f3770>],
#  'caps': [<matplotlib.lines.Line2D at 0x24bd42f38c0>,
#   <matplotlib.lines.Line2D at 0x24bd42f3a10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24bd42f34d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24bd42f3b60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24bd42f3cb0>],
#  'means': []}
