# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\matplotlib-works\\wine-quality-study\\winequality-white.csv",delimiter=";")
print(df.shape)
print(df.columns)
print(df.isnull().sum())
# Out:
# (4898, 12)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# correlation between alcohol and quality
plt.plot(df.groupby("alcohol")["quality"].mean())
print(df[["alcohol","quality","volatile acidity"]].corr()) # heat map is used for correlation
# Out:
#                    alcohol   quality  volatile acidity
# alcohol           1.000000  0.435575          0.067718
# quality           0.435575  1.000000         -0.194723
# volatile acidity  0.067718 -0.194723          1.000000
