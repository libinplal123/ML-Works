# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\matplotlib-works\\earthquake-study\\earthquake.csv")
print(df.shape)
print(df.columns)
# Out:
# (106077, 19)
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status'],
#       dtype='object')

# %%
print(df.isnull().sum())
df["depth"].fillna(df["depth"].mean(),inplace=True)
df["nst"].fillna(df["nst"].mean(),inplace=True)
df["gap"].fillna(df["gap"].mean(),inplace=True)
df["dmin"].fillna(df["dmin"].mean(),inplace=True)
df["rms"].fillna(df["rms"].mode()[0],inplace=True)
df["place"].fillna(df["place"].mode()[0],inplace=True)
df["horizontalError"].fillna(df["horizontalError"].mean(),inplace=True)
df["depthError"].fillna(df["depthError"].mean(),inplace=True)
df["magError"].fillna(df["magError"].mean(),inplace=True)
df["magNst"].fillna(df["magNst"].mean(),inplace=True)
# Out:
# time                   0
# latitude               0
# longitude              0
# depth                593
# mag                    0
# magType                0
# nst                74730
# gap                64091
# dmin               84675
# rms                31517
# id                     0
# updated                0
# place                222
# type                   0
# horizontalError    86094
# depthError         51637
# magError           69523
# magNst             63724
# status                 0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# time               0
# latitude           0
# longitude          0
# depth              0
# mag                0
# magType            0
# nst                0
# gap                0
# dmin               0
# rms                0
# id                 0
# updated            0
# place              0
# type               0
# horizontalError    0
# depthError         0
# magError           0
# magNst             0
# status             0
# dtype: int64

# %%
# all unique places
df["place"].unique()
# Out:
# array(['south of the Fiji Islands', '53 km E of Santiago, Philippines',
#        '16 km ESE of Baculin, Philippines', ...,
#        'The 1838 San Andreas Fault, California Earthquake',
#        'Near San Luis Obispo, California',
#        'Channel Islands region, California'], shape=(64262,), dtype=object)

# %%
# all unique mag types
df["magType"].unique()
# Out:
# array(['mww', 'mb', 'mwr', 'ml', 'mwb', 'mw', 'mwp', 'ml(texnet)', 'mwc',
#        'ms_20', 'Ml', 'ms', 'Md', 'm', 'md', 'mh', 'mlg', 'mc', 'ma',
#        'mb_lg', 'uk', 'fa', 'lg', 'mfa', 'mB', 'mint', 'mj', 'Mfa'],
#       dtype=object)

# %%
# average magnitude by place
df.groupby("place")["mag"].mean()
# Out:
# place
# 0 km E of Avigliana, Italy            5.500000
# 0 km E of Becerreá, Spain             5.100000
# 0 km E of Cervantes, Philippines      5.100000
# 0 km E of Gavaloú, Greece             5.100000
# 0 km E of Golfito, Costa Rica         5.100000
#                                         ...
# western Indian-Antarctic Ridge        5.427977
# western Iran                          5.286667
# western Nei Mongol, China             6.350000
# western Xizang                        5.433208
# western Xizang-India border region    5.750000
# Name: mag, Length: 64262, dtype: float64

# %%
# relation between magType and mag (graph)
plt.plot(df.groupby("magType")["mag"].mean()[:10])
