# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\libin_urv2w13\\Desktop\\mljourney\\Supervised-ML\\Simple-Linear-Reg\\tv-mraketing-process\\salary-process\\Salary_dataset.csv.xls")

# %%
df.columns
# Out:
# Index(['id', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# id                 0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, YearsExperience, Salary]
# Index: []

# %%
df.drop(columns="id",inplace=True)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred)*100)
# Out:
# 95.04404484884267
